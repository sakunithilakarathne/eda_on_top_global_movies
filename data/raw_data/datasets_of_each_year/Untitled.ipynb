# %%
import pandas as pd

# %%
df1 = pd.read_csv("dataset_of_2000.csv")
df2 = pd.read_csv("dataset_of_2001.csv")
df3 = pd.read_csv("dataset_of_2002.csv")
df4 = pd.read_csv("dataset_of_2003.csv")
df5 = pd.read_csv("dataset_of_2004.csv")
df6 = pd.read_csv("dataset_of_2005.csv")
df7 = pd.read_csv("dataset_of_2006.csv")
df8 = pd.read_csv("dataset_of_2007.csv")
df9 = pd.read_csv("dataset_of_2008.csv")
df10 = pd.read_csv("dataset_of_2009.csv")
df11 = pd.read_csv("dataset_of_2010.csv")
df12 = pd.read_csv("dataset_of_2011.csv")
df13 = pd.read_csv("dataset_of_2012.csv")
df14 = pd.read_csv("dataset_of_2013.csv")
df15 = pd.read_csv("dataset_of_2014.csv")
df16 = pd.read_csv("dataset_of_2015.csv")
df17 = pd.read_csv("dataset_of_2016.csv")
df18 = pd.read_csv("dataset_of_2017.csv")
df19 = pd.read_csv("dataset_of_2018.csv")
df20 = pd.read_csv("dataset_of_2019.csv")
df21 = pd.read_csv("dataset_of_2020.csv")

# %%
# Combine all DataFrames into one
combined_df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, 
                         df17, df18, df19, df20, df21  ], ignore_index=True)

# Display the combined DataFrame
display(combined_df)
# Out:
#         imdb_id                    movie_title                     genres  \
# 0     tt0172495                      Gladiator   Action, Adventure, Drama
# 1     tt0120903                          X-Men  Action, Adventure, Sci-Fi
# 2     tt0212346              Miss Congeniality      Action, Comedy, Crime
# 3     tt0160127               Charlie's Angels  Action, Adventure, Comedy
# 4     tt0187393                    The Patriot     Action, Drama, History
# ...         ...                            ...                        ...
# 6995  tt8801584              Sunrise in Heaven             Drama, Romance
# 6996  tt2140571      The Broken Hearts Gallery            Comedy, Romance
# 6997  tt1070874     The Trial of the Chicago 7   Drama, History, Thriller
# 6998  tt7939766  I'm Thinking of Ending Things            Drama, Thriller
# 6999  tt0920462     Lost Girls and Love Hotels            Drama, Thriller
#
#      each_genre  imdb_rating  metascore  vote_count  release_year  \
# ...
